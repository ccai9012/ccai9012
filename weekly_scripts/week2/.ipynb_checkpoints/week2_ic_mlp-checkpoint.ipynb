# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim

# %%
from ccai9012 import nn_utils, viz_utils

# %% [markdown]
# ## Step 1: Load the housing price dataset from sklearn

# %%
# fetching califonia housing price dataset
from sklearn.datasets import fetch_california_housing

california = fetch_california_housing()
X_california = california.data
y_california = california.target
print("California housing dataset loaded.")
print("Feature shape:", X_california.shape)
print("Target shape:", y_california.shape)
print("Feature names:", california.feature_names)
# Out:
# California housing dataset loaded.
# Feature shape: (20640, 8)
# Target shape: (20640,)
# Feature names: ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %%
# Feature explanations for California Housing dataset:
# MedInc    : Median income in the area (in tens of thousands of dollars)
# HouseAge  : Average age of the houses in the area (in years)
# AveRooms  : Average number of rooms per household
# AveBedrms : Average number of bedrooms per household
# Population: Total population in the area
# AveOccup  : Average number of occupants per household
# Latitude  : Geographic latitude of the area
# Longitude : Geographic longitude of the area

# Target variable explanation:
# Target    : Median house value for households within the area (in units of 100,000 dollars)

# showcase the dataset
df = pd.DataFrame(X_california, columns=california.feature_names)
df['Target'] = y_california
df.to_csv("housing_price_california.csv")
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %% [markdown]
# ## Step 2: Prepare input data for model training

# %%
# Normarlize data and prepare dataloaders
train_loader, val_loader, test_loader, scaler = nn_utils.prepare_dataloaders(
    X_california,
    y_california,
    batch_size=64,
    train_ratio=0.8,
    val_ratio=0.1
)

# %% [markdown]
# ## Step 3: Model Build: Two-layer MLP

# %%
class SimpleMLP(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(SimpleMLP, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, 1)  # regression output
        
    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

input_dim = X_california.shape[1]  # 8 features
hidden_dim = 64         # can tune this

model = SimpleMLP(input_dim, hidden_dim)

# %%
# Visualizing the model architecture
viz_utils.draw_simple_mlp(input_size=8,hidden_size=64,output_size=1,hidden_display=5)

# %% [markdown]
# ## Step 4: Model Training

# %%
# Training Setup
learning_rate = 0.001  # step size for optimizer
num_epochs = 50        # number of passes over entire dataset
criterion = nn.MSELoss()  # Mean Squared Error loss for regression
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
train_losses, val_losses = nn_utils.train_model(
    model, 
    train_loader, 
    val_loader, 
    optimizer, 
    criterion, 
    num_epochs
)
# Out:
# Epoch [1/50] - Train Loss: 1.9004, Val Loss: 0.6372
# Epoch [2/50] - Train Loss: 0.6044, Val Loss: 0.4828
# Epoch [3/50] - Train Loss: 0.4898, Val Loss: 0.4161
# Epoch [4/50] - Train Loss: 0.4376, Val Loss: 0.3861
# Epoch [5/50] - Train Loss: 0.4154, Val Loss: 0.3691
# Epoch [6/50] - Train Loss: 0.4006, Val Loss: 0.3605
# Epoch [7/50] - Train Loss: 0.3904, Val Loss: 0.3522
# Epoch [8/50] - Train Loss: 0.3829, Val Loss: 0.3435
# Epoch [9/50] - Train Loss: 0.3772, Val Loss: 0.3354
# Epoch [10/50] - Train Loss: 0.3736, Val Loss: 0.3296
# Epoch [11/50] - Train Loss: 0.3641, Val Loss: 0.3275
# Epoch [12/50] - Train Loss: 0.3577, Val Loss: 0.3218
# Epoch [13/50] - Train Loss: 0.3549, Val Loss: 0.3161
# Epoch [14/50] - Train Loss: 0.3513, Val Loss: 0.3160
# Epoch [15/50] - Train Loss: 0.3451, Val Loss: 0.3118
# Epoch [16/50] - Train Loss: 0.3430, Val Loss: 0.3160
# Epoch [17/50] - Train Loss: 0.3390, Val Loss: 0.3061
# Epoch [18/50] - Train Loss: 0.3337, Val Loss: 0.3006
# Epoch [19/50] - Train Loss: 0.3345, Val Loss: 0.2993
# Epoch [20/50] - Train Loss: 0.3309, Val Loss: 0.3013
# Epoch [21/50] - Train Loss: 0.3279, Val Loss: 0.2939
# Epoch [22/50] - Train Loss: 0.3276, Val Loss: 0.2957
# Epoch [23/50] - Train Loss: 0.3326, Val Loss: 0.2901
# Epoch [24/50] - Train Loss: 0.3239, Val Loss: 0.2898
# Epoch [25/50] - Train Loss: 0.3200, Val Loss: 0.2905
# Epoch [26/50] - Train Loss: 0.3174, Val Loss: 0.2876
# Epoch [27/50] - Train Loss: 0.3149, Val Loss: 0.2960
# Epoch [28/50] - Train Loss: 0.3192, Val Loss: 0.2859
# Epoch [29/50] - Train Loss: 0.3127, Val Loss: 0.2822
# Epoch [30/50] - Train Loss: 0.3134, Val Loss: 0.2888
# Epoch [31/50] - Train Loss: 0.3327, Val Loss: 0.2813
# Epoch [32/50] - Train Loss: 0.3092, Val Loss: 0.2832
# Epoch [33/50] - Train Loss: 0.3103, Val Loss: 0.2797
# Epoch [34/50] - Train Loss: 0.3077, Val Loss: 0.2886
# Epoch [35/50] - Train Loss: 0.3094, Val Loss: 0.2850
# Epoch [36/50] - Train Loss: 0.3065, Val Loss: 0.2816
# Epoch [37/50] - Train Loss: 0.3085, Val Loss: 0.2763
# Epoch [38/50] - Train Loss: 0.3073, Val Loss: 0.2779
# Epoch [39/50] - Train Loss: 0.3086, Val Loss: 0.2804
# Epoch [40/50] - Train Loss: 0.3077, Val Loss: 0.2758
# Epoch [41/50] - Train Loss: 0.3026, Val Loss: 0.2725
# Epoch [42/50] - Train Loss: 0.3036, Val Loss: 0.2788
# Epoch [43/50] - Train Loss: 0.3098, Val Loss: 0.2775
# Epoch [44/50] - Train Loss: 0.3071, Val Loss: 0.2794
# Epoch [45/50] - Train Loss: 0.3014, Val Loss: 0.2817
# Epoch [46/50] - Train Loss: 0.3030, Val Loss: 0.2733
# Epoch [47/50] - Train Loss: 0.3009, Val Loss: 0.2935
# Epoch [48/50] - Train Loss: 0.3021, Val Loss: 0.2758
# Epoch [49/50] - Train Loss: 0.2993, Val Loss: 0.2800
# Epoch [50/50] - Train Loss: 0.2982, Val Loss: 0.2777

# %%
# Plot Training and Validation Loss
viz_utils.plot_loss_curve(train_losses, val_losses)

# %% [markdown]
# ## Step 5: Test Model Performance

# %%
results = nn_utils.evaluate_regression_model(
    model,
    test_loader,
    show_examples=True,
    metrics=['rmse', 'mse', 'mae', 'mape']
)
# Out:
# MSE: 0.3275
# RMSE: 0.5723
# MAE: 0.3936
# MAPE: 23.33%
# R^2 Score: 0.7620
