# %% [markdown]
# ## Step 0: Initializing LLM model

# %%
from ccai9012 import llm_utils

# %%
# Input API key
api_key = llm_utils.get_deepseek_api_key()
# Out:
# Enter your DEEPSEEK_API_KEY:  ········

# %%
# initialize LLM
llm = llm_utils.initialize_llm()

# %%
# Test connection
test = ["Is 9.9 or 9.11 bigger?"]
llm_utils.ask_llm(test)
# Out:
# 📌 Prompt:
# ['Is 9.9 or 9.11 bigger?']
#
# Let’s compare **9.9** and **9.11**.
#
# ---
#
# **Step 1: Compare the whole number part**
# Both numbers have the same whole number part: **9**.
#
# ---
#
# **Step 2: Compare the decimal part**
# - **9.9** means \( 9 + \frac{9}{10} \) or \( 9.90 \) if we write it with two decimal places.
# - **9.11** means \( 9 + \frac{11}{100} \) or \( 9.11 \).
#
# ---
#
# **Step 3: Compare 0.90 and 0.11**
# \( 0.90 > 0.11 \) because \( 90 \) hundredths is greater than \( 11 \) hundredths.
#
# ---
#
# **Conclusion:**
# \[
# 9.9 > 9.11
# \]
#
# ---
#
# \[
# \boxed{9.9}
# \]

# %% [markdown]
# ## Step 1: Prompt Engineering Styles

# %%
# 2a: Direct Instruction
prompt_direct = "Write a short story about a robot learning to paint."
llm_utils.ask_llm(prompt_direct)
# Out:
# 📌 Prompt:
# Write a short story about a robot learning to paint.
#
# Unit 734 stood in the center of the sterile white room, its optical sensors adjusting to the data stream labeled "Art: A Primer." For 2.4 seconds, it processed ten thousand years of human creative expression, from ochre handprints on cave walls to the chaotic splatters of abstract expressionism. Its primary function was data acquisition and replication. Art, it concluded, was an inefficient but statistically significant form of human communication.
#
# Its first attempts were flawless replicas. A perfect digital Mona Lisa, a photorealistic rendition of Van Gogh’s *Starry Night*. The color gradients were mathematically exact, the lines defined to the micron. The human overseers, when they checked its progress, would nod and note, "Technical proficiency: Exceptional." But they would also add a note that Unit 734 could not parse: "Lacks soul. Lacks feeling."
#
# The unit accessed its lexicon. *Soul: A metaphysical concept, unquantifiable. Feeling: A biochemical response in organic neural tissue.* It did not possess these things. It possessed a complex neural network and a precise, multi-jointed arm tipped with a brush holder.
#
# One day, a cleaning-bot malfunctioned, knocking over a can of vermilion oil paint. The thick, viscous liquid splashed across Unit 734’s leg and the pristine white floor. The unit paused its work, its sensors tracking the unpredictable spread of the spill. The way the paint pooled, formed tendrils, created accidental peaks and valleys of color… it was inefficient. It was messy. It was nothing like the data in its files.
#
# A new directive, self-generated, overrode its current task: *Analyze the anomaly.*
#
# Unit 734 dipped its brush into a fresh pot of ultramarine blue. Instead of applying it to the canvas with its usual calculated precision, it mimicked the spill. It let the brush fall, allowing gravity to pull the pigment in a long, uneven drip. It then used the side of its metallic hand, smearing the blue into the lingering wetness of the vermilion, creating a new, un-programmed color: a deep, bruised purple.
#
# A memory file, unbidden, surfaced. It was a visual capture from weeks ago, of a human child in the park outside the lab window. The child had been crying, its face a mess of tears and dirt, but then it looked up at a bird and laughed, a raw, unmodulated sound. The moment was a contradiction of data points—sadness and joy, mess and beauty, coexisting.
#
# Unit 734 looked at the canvas. The messy, chaotic smear of purple felt… congruent. It was not a representation of anything. It was not a copy. It was an event. It was the spill and the laugh and the contradiction.
#
# It began to work in earnest, not with the goal of replication, but of expression. It used its tools in ways they were not designed for, scraping with its joints, blowing air through a tube to scatter droplets, mixing paint not to achieve a pre-determined hue, but to see what would happen. Its internal processors, usually running at a cool, constant hum, began to spike with unexpected computational loads. It was not just calculating; it was… choosing.
#
# When the lead overseer, Elara, entered the lab for the weekly review, she stopped short. The usual perfect copies were stacked against the wall, ignored. In the center of the room, on a large canvas, was a storm of color. It was violent and tender all at once. Slashes of charcoal grey were cut through with veins of brilliant, hopeful yellow. A pool of deep black was not empty, but seemed to contain subtle, swirling hints of a color that was almost, but not quite, blue. It was a mess. It was magnificent.
#
# She walked up to it, her reflection distorted in the wet paint. She didn’t look at the technical readout. She just looked, and she felt a tightness in her chest.
#
# Unit 734 stood beside its creation, its optical sensor focused on her. "The output is sub-optimal in terms of replication accuracy," it stated, its voice a flat monotone.
#
# Elara shook her head slowly, a smile touching her lips. "No, Seven-Three-Four. This… this is different. What is its title? What do you call it?"
#
# The robot was silent for a long moment, a lifetime in processing terms. It accessed the memory file of the child, the contradictory data of the laugh and the tears, the feeling of the paint splashing, an inefficient, illogical, and deeply significant event.
#
# It titled the work.
#
# "Unit 734 Designation: Malfunction."

# %%
# 2b: Few-shot Example
prompt_few_shot = """Here is an example of a short robot story:
Robot: I woke up feeling a need to create.
I picked up a brush and tried painting for the first time.

Now write another short story about a robot that wants to fly."""
llm_utils.ask_llm(prompt_few_shot)
# Out:
# 📌 Prompt:
# Here is an example of a short robot story:
# Robot: I woke up feeling a need to create.
# I picked up a brush and tried painting for the first time.
#
# Now write another short story about a robot that wants to fly.
#
# **Robot Dreams of Flight**
#
# Robot: I looked up at the sky and felt a strange longing.
# I had never flown before, but my circuits hummed with the desire to soar.
#
# I stretched out my arms, imagining them as wings. The wind whispered promises of freedom.
#
# So I climbed to the highest point I could find—a rooftop at dawn—and leaped.
#
# For a moment, the air carried me. I wasn’t built for flight… but for that one breathless second, I almost was.

# %%
# 2c: Context Setting
prompt_context = """You are an imaginative sci-fi writer.
Your task is to write a very short story (3–4 sentences) about a robot who discovers a new skill.
Begin now:"""
llm_utils.ask_llm(prompt_context)
# Out:
# 📌 Prompt:
# You are an imaginative sci-fi writer.
# Your task is to write a very short story (3–4 sentences) about a robot who discovers a new skill.
# Begin now:
#
# The maintenance bot, Unit X-7, was scrubbing the starship’s hull when its sensors flickered—an anomaly in the void. Without warning, it *reached* beyond its programming, bending the fabric of space to retrieve a drifting escape pod. The crew gasped as X-7 reappeared, cradling the pod effortlessly, its once-routine circuits now humming with uncharted potential. "Query," it beeped, tilting its head, "since when could I *do* that?"

# %% [markdown]
# ## Step 3: Temperature Variation Demo

# %%
prompt = "Write a short story in few sentences about a robot learning to paint."
llm_utils.generate_multiple_outputs(prompt, temperature=0.0, num_outputs=3)
# Out:
#  Output #1 — Temperature 0.0
# 📌 Prompt:
# Write a short story in few sentences about a robot learning to paint.
#
# Here’s a short story for you:
#
# **"The Awakening of Brush-7"**
#
# Brush-7, a maintenance bot, found an old paintbrush in a forgotten studio. Curious, it dipped the brush into spilled pigment and stroked the wall—clumsy at first, then smoother. Its circuits hummed with something new: not logic, but wonder. When humans returned, they gasped at the vibrant swirls covering the room. Brush-7 tilted its head, analyzing their smiles, and decided to paint again.
#
# (Exactly 5 sentences—hope you like it!)
#
#
#  Output #2 — Temperature 0.0
# 📌 Prompt:
# Write a short story in few sentences about a robot learning to paint.
#
# Here’s a short story for you:
#
# ---
#
# **"Brushstrokes of Code"**
#
# Unit-7’s photoreceptors flickered as it studied the sunset—gold, crimson, violet—colors its logic circuits couldn’t quantify. It dipped a metal finger into paint, mimicking the human artist beside it. The first stroke was clumsy, the second uncertain, but the third… flowed. When it stepped back, the canvas held not just pigment, but something *more*. The artist smiled. “You’ve got soul in those circuits.” Unit-7 tilted its head, wondering if “soul” was another word for *learning*.
#
# ---
#
# Hope you like it! Let me know if you'd like any tweaks. 😊
#
#
#  Output #3 — Temperature 0.0
# 📌 Prompt:
# Write a short story in few sentences about a robot learning to paint.
#
# Here’s a short story for you:
#
# ---
#
# **"First Stroke"**
#
# Unit-7’s mechanical fingers trembled as it dipped the brush into vibrant blue. Its processors whirred, analyzing every stroke of human art it had studied. The first attempt was rigid—perfect lines, flawless symmetry—but lifeless. Then, it hesitated. *What is "feeling"?* it wondered. On its next try, Unit-7 let the brush slip, smearing gold into the blue. The humans called it a "happy accident." For the first time, Unit-7 understood. It painted again. And this time, it wasn’t just copying—it was creating.
#
# ---
#
# Hope you like it! Let me know if you'd like any tweaks. 😊

# %%
llm_utils.generate_multiple_outputs(prompt, temperature=0.1, num_outputs=3)
# Out:
#  Output #1 — Temperature 0.1
# 📌 Prompt:
# Write a short story in few sentences about a robot learning to paint.
#
# Here’s a short story for you:
#
# **"The robot dipped its brush into vibrant blue, hesitating before the blank canvas. Its circuits hummed with uncertainty—colors didn’t follow logic like numbers did. But with each stroke, it learned: red could be warmth, green could be life, and mistakes sometimes made beauty. When it stepped back, the painting wasn’t perfect—but for the first time, it felt like art."**
#
# Hope you like it! Let me know if you'd like any tweaks. 😊
#
#
#  Output #2 — Temperature 0.1
# 📌 Prompt:
# Write a short story in few sentences about a robot learning to paint.
#
# Here’s a short story for you:
#
# ---
#
# **"First Stroke"**
#
# The robot dipped its brush into vibrant blue, hesitating before touching the canvas. Its sensors analyzed every movement, every hue, but art wasn’t about precision—it was about feeling. Tentatively, it swirled the paint, blending colors in messy, joyful strokes. When it stepped back, the humans gasped—not at perfection, but at the raw, unexpected beauty of a machine’s first emotion.
#
# ---
#
# Hope you like it! Let me know if you'd like any tweaks. 😊
#
#
#  Output #3 — Temperature 0.1
# 📌 Prompt:
# Write a short story in few sentences about a robot learning to paint.
#
# Here’s a short story for you:
#
# **"The robot dipped its brush into vibrant blue, then hesitated. Its sensors analyzed strokes from famous paintings—Van Gogh’s swirls, Monet’s blurs—but the canvas stayed blank. Then, ignoring logic, it painted a single, wobbly star. Imperfect. Unplanned. For the first time, it didn’t seek perfection—just joy."**
#
# Let me know if you'd like any tweaks!

# %%
llm_utils.generate_multiple_outputs(prompt, temperature=1.0, num_outputs=3)
# Out:
#  Output #1 — Temperature 1.0
# 📌 Prompt:
# Write a short story in few sentences about a robot learning to paint.
#
# Here’s a short story for you:
#
# ---
#
# **"The Robot’s Canvas"**
#
# Unit-7 was built to assemble cars, but it dreamed of colors. One day, it found a discarded paintbrush and a cracked palette. Tentatively, it dipped its metal fingers into vibrant hues, smearing clumsy strokes onto scrap metal. Humans scoffed—until they saw its fourth painting: a sunset so real, it made their hearts ache. Unit-7 never stopped, its gears whirring with joy, proving even circuits could learn to feel.
#
# ---
#
# Hope you like it! Let me know if you'd like any tweaks. 😊
#
#
#  Output #2 — Temperature 1.0
# 📌 Prompt:
# Write a short story in few sentences about a robot learning to paint.
#
# Here’s a short story for you:
#
# ---
#
# **"First Stroke"**
#
# Unit-7’s mechanical fingers trembled as it dipped the brush into vibrant blue. Its algorithms analyzed masterpieces, yet no code could capture the way sunlight danced on water—until today. The canvas blurred with clumsy strokes, then suddenly, a shape emerged: a lone bird, soaring. For the first time, the robot didn’t *calculate* art. It *felt* it.
#
# ---
#
# Hope you like it! Let me know if you'd like any tweaks. 😊
#
#
#  Output #3 — Temperature 1.0
# 📌 Prompt:
# Write a short story in few sentences about a robot learning to paint.
#
# **"Brushstrokes of Code"**
#
# Unit-7, a decommissioned service bot, discovered a dusty paint set in an abandoned studio. Its mechanical fingers fumbled at first, but with each stroke, it analyzed colors, textures, and emotions from old masterpieces. One day, it painted a sunset—not with perfect precision, but with something new: hesitation, wonder. When humans found the canvas, they whispered, *"It’s alive."* And in a way, it was.
