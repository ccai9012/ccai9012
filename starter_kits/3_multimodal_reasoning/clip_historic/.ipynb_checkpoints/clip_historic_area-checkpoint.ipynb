# %% [markdown]
# ## Step 1: Choose a historic area and sample points along the streets

# %%
import numpy as np
import pandas as pd
import folium
import osmnx as ox
from shapely.geometry import box

# %%
# Define the bounding box coordinates (Barcelona – Eixample + 22@ Innovation District, Spain)
lat_min, lat_max = 41.3975, 41.4065
lon_min, lon_max = 2.1780, 2.2030

# Create a Folium map centered in the middle of the bounding box
map_center = [(lat_min + lat_max) / 2, (lon_min + lon_max) / 2]
m = folium.Map(location=map_center, zoom_start=15, tiles="cartodbpositron")

# Define the bounding box as a list of corner points (in order)
bounding_box = [
    [lat_min, lon_min],  # bottom-left
    [lat_min, lon_max],  # bottom-right
    [lat_max, lon_max],  # top-right
    [lat_max, lon_min],  # top-left
    [lat_min, lon_min]   # close the polygon
]

# Add a red PolyLine (rectangle) to the map
folium.PolyLine(
    locations=bounding_box,
    color="red",
    weight=3,
    opacity=0.8
).add_to(m)

# display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import osmnx as ox
import geopandas as gpd
import numpy as np
import folium
from shapely.geometry import Point
from pyproj import Transformer
from scipy.spatial import KDTree

# --------------------------
# Function to sample points along a linestring at approx. regular intervals
def sample_points_along_line(line, dist=20):
    length = line.length
    points = []
    for d in np.arange(0, length, dist):
        point = line.interpolate(d)
        points.append(point)
    return points
    
# KDTree filtering function
def filter_points_kdtree(points_proj, min_distance_m=50):
    if not points_proj:
        return []
    
    # Convert Points to numpy array for KDTree
    xy = np.array([[pt.x, pt.y] for pt in points_proj])
    
    # Build KDTree for efficient neighbor queries
    tree = KDTree(xy)
    kept_idx = []
    visited = np.zeros(len(xy), dtype=bool)
    
    for i in range(len(xy)):
        if not visited[i]:
            kept_idx.append(i)
            # Mark all neighbors within radius as visited
            neighbors = tree.query_ball_point(xy[i], r=min_distance_m)
            visited[neighbors] = True
    
    return [points_proj[i] for i in kept_idx]

# --------------------------
# Main workflow

# Define bounding box and map center
bbox = (lon_min, lat_min, lon_max, lat_max)

# Download street network graph within bounding box (all network types)
G = ox.graph_from_bbox(bbox, network_type='all')

# Project graph to a metric CRS (meters)
G_proj = ox.project_graph(G)

# Extract edges as GeoDataFrame (geometry column contains LineStrings)
edges = ox.graph_to_gdfs(G_proj, nodes=False, edges=True)



# Sample points from all edges
sampled_points_proj = []
for line in edges.geometry:
    sampled_points_proj.extend(sample_points_along_line(line, dist=100))

# Filter points so that they are spaced at least min_distance_m apart
filtered_points_proj = filter_points_kdtree(sampled_points_proj, min_distance_m=50)

# Convert filtered points from projected CRS back to latitude/longitude
project_crs = edges.crs
to_latlon = Transformer.from_crs(project_crs, "EPSG:4326", always_xy=True)
sampled_points_latlon = [to_latlon.transform(pt.x, pt.y)[::-1] for pt in filtered_points_proj]  # (lat, lon)

# Create folium map centered on map_center
m = folium.Map(location=map_center, zoom_start=15, tiles="cartodbpositron")

# Add a red PolyLine rectangle to show bounding box
folium.PolyLine(
    locations=bounding_box,
    color="red",
    weight=3,
    opacity=0.8
).add_to(m)

# Add blue CircleMarkers for sampled points
for lat, lon in sampled_points_latlon:
    folium.CircleMarker(
        location=[lat, lon],
        radius=1,
        color='blue',
        fill=True,
        fill_opacity=0.5
    ).add_to(m)
m.save("Barcelona.html")

print(f"In total {len(sampled_points_latlon)} points")
display(m)
# Out:
# In total 291 points
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## Step 2: Pull Street View Images (SVI) from Google Map

# %%
import os
import requests
import numpy as np
from PIL import Image
from io import BytesIO
from tqdm import tqdm

# %%
if not os.getenv("GOOGLEMAP_API_KEY"):
    os.environ["GOOGLEMAP_API_KEY"] = getpass.getpass("Enter your Google Map API key: ")

# %%
# Google Maps API settings
API_KEY = os.environ["GOOGLEMAP_API_KEY"] 
BASE_URL = "https://maps.googleapis.com/maps/api/streetview"
META_URL = "https://maps.googleapis.com/maps/api/streetview/metadata"

# %%
def download_streetview_image(lat, lon, heading=0, pitch=0, fov=90, size="640x640", save=True):
    params = {
        "location": f"{lat},{lon}",
        "size": size,
        "heading": heading,
        "pitch": pitch,
        "fov": fov,
        "source": "outdoor",
        "key": API_KEY
    }
    response = requests.get(BASE_URL, params=params)

    if response.status_code == 200:
        image = Image.open(BytesIO(response.content))
        if save:
            filename = f"lat{lat:.6f}_lon{lon:.6f}_hdg{heading}.jpg"
            filepath = os.path.join(SAVE_DIR, filename)
            image.save(filepath)
            return filepath
        return image
    else:
        return None

# %%
# Where to save images
SAVE_DIR = "images"
os.makedirs(SAVE_DIR, exist_ok=True)

# Camera headings (direction in degrees: 0 = North, 90 = East, etc.)
HEADINGS = [90, 270]  # capture 2 directions

# Download SVI for each grid point and heading
for lat, lon in tqdm(sampled_points_latlon, desc="Downloading SVI"):
    for heading in HEADINGS:
        filepath = download_streetview_image(lat, lon, heading=heading)
        if not filepath:
            print(f"✗ Failed: lat={lat:.6f}, lon={lon:.6f}, heading={heading}")

# %% [markdown]
# ## Step 3: Classfication with CLIP

# %%
from PIL import Image
import requests
from transformers import CLIPProcessor, CLIPModel

# %%
# download the CLIP model from huggingface
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

# %%
# Classification function for one image
def classify_image_clip(image_path, text_prompts):
    try:
        image = Image.open(image_path).convert("RGB")
    except:
        print(f"Failed to open image: {image_path}")
        return None

    # Process image and prompts
    inputs = processor(text=text_prompts, images=image, return_tensors="pt", padding=True)

    with torch.no_grad():
        outputs = model(**inputs)
        logits_per_image = outputs.logits_per_image
        probs = logits_per_image.softmax(dim=1)  # Convert logits to probabilities

    # Return top category and full scores
    top_idx = probs.argmax().item()
    return {
        "filename": os.path.basename(image_path),
        "label_id": top_idx,
        "label_text": text_prompts[top_idx],
        "confidence": probs[0, top_idx].item(),
        "all_scores": probs.squeeze().tolist()
    }

# %%
# Directory where street view images are saved
image_dir = "images"

# Get all image file paths ending with .jpg in the directory
image_paths = [os.path.join(image_dir, f) for f in os.listdir(image_dir) if f.endswith(".jpg")]

# Define visual prompt categories (tailored to Barcelona region)
text_prompts = [
    "historic or traditional European buildings made of brick or stone",  # 0 - Historic
    "modern buildings with glass, metal, concrete or painted facade",                            # 1 - Modern
    "a combination of historic and modern buildings in the same scene, showing contrast in architectural styles",             # 2 - Mixed
    "an open public space such as a plaza, park, or square, with no visible buildings in the frame, featuring trees or sky"    # 3 - Open Space
]

# Placeholder for inference results
results = []

# Run inference on each image and collect the results
for img_path in tqdm(image_paths, desc="Running inference"):
    result = classify_image_clip(img_path, text_prompts)
    results.append(result)

# Convert list of results to pandas DataFrame
df = pd.DataFrame(results)

# Save DataFrame to CSV file
csv_path = "inference_results.csv"
df.to_csv(csv_path, index=False)

print(f"Inference results saved to {csv_path}")
# Out:
# Running inference: 100%|██████████████████████████████████████████████████████| 582/582 [00:28<00:00, 20.27it/s]
# Inference results saved to inference_results.csv

# %%
type(df['all_scores'])
# Out:
# pandas.core.series.Series

# %%
def show_inference_result(df, index=0):
    row = df.iloc[index]

    img_path = row['filename']
    label_id = row['label_id']
    label_text = row['label_text']
    confidence = row['confidence']

    img = Image.open(os.path.join(image_dir,img_path))

    plt.figure(figsize=(6,6))
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"Label: {label_text}\nConfidence: {confidence:.2f}")
    plt.show()

import random
random_indices = random.sample(range(len(df)), 5)
for index in random_indices:
    show_inference_result(df, index=index)

# %% [markdown]
# ## Step 4: Generate Historic Index Heatmap

# %%
import ast
from folium.plugins import HeatMap

# %%
# Parse lat, lon, heading from filename
def parse_filename(fname):
    m = re.match(r'lat([-.\d]+)_lon([-.\d]+)_hdg(\d+)\.jpg', fname)
    if m:
        lat = float(m.group(1))
        lon = float(m.group(2))
        heading = int(m.group(3))
        return lat, lon, heading
    else:
        return None, None, None

df[['lat', 'lon', 'heading']] = df['filename'].apply(lambda x: pd.Series(parse_filename(x)))

# Define weights for label_id: 0->3, 1->2, 2->1, 3->0 (ignore)
weights = {0: 3, 1: 2, 2: 1, 3: 0}

def weighted_score(scores):
    # scores is a list of confidences corresponding to [id0, id1, id2, id3]
    total_weight = 3 + 2 + 1  # sum of weights for id 0,1,2
    score_sum = scores[0]*3 + scores[1]*2 + scores[2]*1
    return score_sum / total_weight

# Calculate weighted score per row
df['weighted_score'] = df['all_scores'].apply(weighted_score)

# Group by lat, lon and average weighted scores over headings
grouped = df.groupby(['lat', 'lon'])['weighted_score'].mean().reset_index()
grouped
# Out:
#            lat       lon  weighted_score
# 0    41.397528  2.181091        0.474869
# 1    41.397550  2.183534        0.213274
# 2    41.397558  2.192852        0.283861
# 3    41.397564  2.185608        0.282243
# 4    41.397578  2.178792        0.252033
# ..         ...       ...             ...
# 286  41.406310  2.197982        0.293397
# 287  41.406404  2.198688        0.413406
# 288  41.406445  2.186190        0.370566
# 289  41.406473  2.179443        0.488023
# 290  41.406492  2.196274        0.414149
#
# [291 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import branca.colormap as cm

# create folium map
m = folium.Map(location=map_center, zoom_start=15, tiles='cartodbpositron')

# Prepare colormap
vmin, vmax = grouped['weighted_score'].min(), grouped['weighted_score'].max()
print(vmin, vmax)

colormap = cm.LinearColormap(
    colors=['blue', 'green', 'yellow', 'red'], 
    vmin=0,
    vmax=0.5,
    caption='Weighted Historic Building Index' 
)

# mapping points
for _, row in grouped.iterrows():
    lat, lon, score = row['lat'], row['lon'], row['weighted_score']
    color = colormap(score)

    folium.CircleMarker(
        location=[lat, lon],
        radius=7,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.7,
        popup=f"Score: {score:.2f}"
    ).add_to(m)

colormap.add_to(m)

m.save("colored_points_heatmap_with_legend.html")
m
# Out:
# 0.016204173235261504 0.49738298121277086
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Prepare heatmap data
heat_data = grouped[['lat', 'lon', 'weighted_score']].values.tolist()

# Create folium map centered on average location
map_center = [grouped['lat'].mean(), grouped['lon'].mean()]
m = folium.Map(location=map_center, zoom_start=14, tiles='cartodbpositron')

# Add heatmap layer
HeatMap(heat_data, radius=15, max_zoom=17).add_to(m)

# Save or display map
m.save('weighted_historic_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
